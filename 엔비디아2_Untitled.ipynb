# %% [markdown]
# <a href="https://colab.research.google.com/github/dembor5317/NBDIA/blob/main/%EC%97%94%EB%B9%84%EB%94%94%EC%95%842_Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ✅ 1. YOLOv8 설치
# !pip install -q ultralytics

# ✅ 2. 라이브러리 임포트
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
from google.colab import files
import os

# ✅ 3. 모델 로드
model = YOLO('yolov8x.pt')  # 고정밀 모델

# ✅ 4. 동영상 업로드
uploaded = files.upload()

# ✅ 5. 업로드한 동영상 파일 경로 확인
video_path = next(iter(uploaded))

# ✅ 6. 비디오 읽기 및 출력 비디오 준비
cap = cv2.VideoCapture(video_path)

# 출력 비디오 설정
output_path = 'output_vehicle_detection.mp4'
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
fps = cap.get(cv2.CAP_PROP_FPS)
w = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
h = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
out = cv2.VideoWriter(output_path, fourcc, fps, (w, h))

# ✅ 7. 프레임 처리
frame_num = 0
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # YOLO 추론 (자동차 관련 클래스만)
    results = model(frame, verbose=False)[0]

    vehicle_count = 0
    for box in results.boxes:
        cls_id = int(box.cls[0])
        # 자동차, 트럭, 버스만 필터링
        if cls_id in [2, 5, 7]:
            vehicle_count += 1

    # 주석 포함된 이미지 가져오기
    annotated_frame = results.plot()

    # 차량 수 텍스트 추가
    cv2.putText(
        annotated_frame,
        f'Vehicles: {vehicle_count}',
        (20, 40),
        cv2.FONT_HERSHEY_SIMPLEX,
        1.2,
        (0, 255, 0),
        3
    )

    out.write(annotated_frame)
    frame_num += 1
    if frame_num % 30 == 0:
        print(f'{frame_num} 프레임 처리 완료...')

cap.release()
out.release()

# ✅ 8. 결과 비디오 다운로드 링크 제공
from IPython.display import HTML
from base64 import b64encode

def download_video(path):
    mp4 = open(path, 'rb').read()
    data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
    return HTML(f'')

download_video(output_path)
# ✅ 코랩에서 동영상 미리보기
from IPython.display import HTML
from base64 import b64encode

def show_video(path):
    mp4 = open(path, 'rb').read()
    data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
    return HTML(f"""
    """)

# 출력 동영상 경로에 맞춰 실행
show_video('output_vehicle_detection.mp4')
# Out:
#      <input type="file" id="files-d14eb98c-adcb-4a34-a449-866cca078b0f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d14eb98c-adcb-4a34-a449-866cca078b0f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
